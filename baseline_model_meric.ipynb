# %% [markdown]
# <a href="https://colab.research.google.com/github/mericgn/gz-dbt-repository/blob/main/baseline_model_meric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("2017-selected-columns.csv")

# Tablodaki tüm sütunların tam ve gerçek isimlerini yazdır
print(df.columns.tolist())
# Out:
# ['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF']

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("2017-selected-columns.csv")


df['TARGET_DELAY_15'] = np.where(df['DEP_DELAY'] >= 15, 1, 0)

kullanilacak_kolonlar = [
    'FL_DATE',
    'OP_CARRIER',
    'ORIGIN',
    'DEST',
    'TARGET_DELAY_15'
]

df_baseline = df[kullanilacak_kolonlar]
df_baseline.head()
# Out:
#    FL_DATE  OP_CARRIER  ORIGIN  DEST  TARGET_DELAY_15
# 0      NaN         NaN     NaN   NaN                0
# 1      NaN         NaN     NaN   NaN                0
# 2      NaN         NaN     NaN   NaN                0
# 3      NaN         NaN     NaN   NaN                0
# 4      NaN         NaN     NaN   NaN                0
